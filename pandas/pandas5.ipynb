# %%
r = df3['cgpa'].mean()
r
# Out:
# 10.47

# %%
f = df3['cgpa'].median()

# %%
g = df3.filter(items = ['cgpa', 'placed'])
g
# Out:
#     cgpa  placed
# 0     12       1
# 1     10       0
# 2     12       1
# 3     10       1
# 4     11       1
# ..   ...     ...
# 95    10       0
# 96    12       1
# 97    10       0
# 98    12       1
# 99    10       0
#
# [100 rows x 2 columns]

# %%
df3[['cgpa', 'placed']]
# Out:
#     cgpa  placed
# 0     12       1
# 1     10       0
# 2     12       1
# 3     10       1
# 4     11       1
# ..   ...     ...
# 95    10       0
# 96    12       1
# 97    10       0
# 98    12       1
# 99    10       0
#
# [100 rows x 2 columns]

# %%
s = df3.filter(items = [3,4,5,6], axis = 0)
s
# Out:
#    cgpa  resume_score  placed
# 3    10             7       1
# 4    11             7       1
# 5    12             6       1
# 6     9             7       0

# %%
p = df3.rename(columns = {'cgpa': 'updated_cgpa','resume_score': 'semester_markds'})
p
# Out:
#     updated_cgpa  semester_markds  placed
# 0             12                6       1
# 1             10                5       0
# 2             12                8       1
# 3             10                7       1
# 4             11                7       1
# ..           ...              ...     ...
# 95            10                6       0
# 96            12                7       1
# 97            10                7       0
# 98            12                5       1
# 99            10                6       0
#
# [100 rows x 3 columns]

# %%
df3['half'] = df3['cgpa'].where(df3['cgpa']>10, other =0)
df3.head(10)
# Out:
#    cgpa  resume_score  placed  half
# 0    12             6       1    12
# 1    10             5       0     0
# 2    12             8       1    12
# 3    10             7       1     0
# 4    11             7       1    11
# 5    12             6       1    12
# 6     9             7       0     0
# 7    10             6       0     0
# 8    10             6       0     0
# 9    11             7       1    11

# %%
df3.columns
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
df3
# Out:
#     cgpa  resume_score  placed
# 0     12             6       1
# 1     10             5       0
# 2     12             8       1
# 3     10             7       1
# 4     11             7       1
# ..   ...           ...     ...
# 95    10             6       0
# 96    12             7       1
# 97    10             7       0
# 98    12             5       1
# 99    10             6       0
#
# [100 rows x 3 columns]

# %%
df4= pd.read_csv("covid_toy.csv")
df4
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df4['gender'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df4['gender'] = df4['gender'].map({"Female":0 , "Male":1})

# %%
df4['cough'] = df4['cough'].map({"Mild":0 , "Strong":1})

# %%
df4
# Out:
#     age  gender  fever  cough       city has_covid
# 0    60     NaN  103.0    NaN    Kolkata        No
# 1    27     NaN  100.0    NaN      Delhi       Yes
# 2    42     NaN  101.0    NaN      Delhi        No
# 3    31     NaN   98.0    NaN    Kolkata        No
# 4    65     NaN  101.0    NaN     Mumbai        No
# ..  ...     ...    ...    ...        ...       ...
# 95   12     NaN  104.0    NaN  Bangalore        No
# 96   51     NaN  101.0    NaN    Kolkata       Yes
# 97   20     NaN  101.0    NaN  Bangalore        No
# 98    5     NaN   98.0    NaN     Mumbai        No
# 99   10     NaN   98.0    NaN    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
d = df5.size
d
# Out:
# 600

# %%
i = df5.ndim
i
# Out:
# 2

# %%
a = df5.values
a
# Out:
# array([[60, 1, 103.0, 0, 'Kolkata', 0],
#        [27, 1, 100.0, 0, 'Delhi', 1],
#        [42, 1, 101.0, 0, 'Delhi', 0],
#        [31, 0, 98.0, 0, 'Kolkata', 0],
#        [65, 0, 101.0, 0, 'Mumbai', 0],
#        [84, 0, nan, 0, 'Bangalore', 1],
#        [14, 1, 101.0, 1, 'Bangalore', 0],
#        [20, 0, nan, 1, 'Mumbai', 1],
#        [19, 0, 100.0, 1, 'Bangalore', 0],
#        [64, 0, 101.0, 0, 'Delhi', 0],
#        [75, 0, nan, 0, 'Delhi', 0],
#        [65, 0, 98.0, 0, 'Mumbai', 1],
#        [25, 0, 99.0, 1, 'Kolkata', 0],
#        [64, 1, 102.0, 0, 'Bangalore', 1],
#        [51, 1, 104.0, 0, 'Bangalore', 0],
#        [70, 1, 103.0, 1, 'Kolkata', 1],
#        [69, 0, 103.0, 0, 'Kolkata', 1],
#        [40, 0, 98.0, 1, 'Delhi', 0],
#        [64, 0, 98.0, 0, 'Bangalore', 1],
#        [42, 0, nan, 1, 'Bangalore', 1],
#        [12, 1, 98.0, 1, 'Bangalore', 0],
#        [73, 1, 98.0, 0, 'Bangalore', 1],
#        [71, 0, 98.0, 1, 'Kolkata', 1],
#        [80, 0, 98.0, 0, 'Delhi', 1],
# ...

# %%
g = df5.sort_values(by = 'city')
g
# Out:
#     age  gender  fever  cough       city  has_covid
# 65   69       0  102.0      0  Bangalore          0
# 36   38       0  101.0      0  Bangalore          0
# 35   82       0  102.0      1  Bangalore          0
# 43   22       0   99.0      0  Bangalore          1
# 67   65       1   99.0      0  Bangalore          0
# ..  ...     ...    ...    ...        ...        ...
# 55   81       0  101.0      0     Mumbai          1
# 58   23       1   98.0      1     Mumbai          1
# 61   81       0   98.0      1     Mumbai          0
# 29   34       0    NaN      1     Mumbai          1
# 49   44       1  104.0      0     Mumbai          0
#
# [100 rows x 6 columns]

# %%
df5['age'] = df5['age'].astype(float)

# %%
df5
# Out:
#      age  gender  fever  cough       city  has_covid
# 0   60.0       1  103.0      0    Kolkata          0
# 1   27.0       1  100.0      0      Delhi          1
# 2   42.0       1  101.0      0      Delhi          0
# 3   31.0       0   98.0      0    Kolkata          0
# 4   65.0       0  101.0      0     Mumbai          0
# ..   ...     ...    ...    ...        ...        ...
# 95  12.0       0  104.0      0  Bangalore          0
# 96  51.0       0  101.0      1    Kolkata          1
# 97  20.0       0  101.0      0  Bangalore          0
# 98   5.0       0   98.0      1     Mumbai          0
# 99  10.0       0   98.0      1    Kolkata          1
#
# [100 rows x 6 columns]

# %%
l = df5

# %%
l['has_covid'] = l['has_covid'].astype(float)

# %%
l
# Out:
#      age  gender  fever  cough       city  has_covid
# 0   60.0       1  103.0      0    Kolkata        0.0
# 1   27.0       1  100.0      0      Delhi        1.0
# 2   42.0       1  101.0      0      Delhi        0.0
# 3   31.0       0   98.0      0    Kolkata        0.0
# 4   65.0       0  101.0      0     Mumbai        0.0
# ..   ...     ...    ...    ...        ...        ...
# 95  12.0       0  104.0      0  Bangalore        0.0
# 96  51.0       0  101.0      1    Kolkata        1.0
# 97  20.0       0  101.0      0  Bangalore        0.0
# 98   5.0       0   98.0      1     Mumbai        0.0
# 99  10.0       0   98.0      1    Kolkata        1.0
#
# [100 rows x 6 columns]
